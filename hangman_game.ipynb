# %% [markdown]
# <a href="https://colab.research.google.com/github/Nafay962/piaic_compulsary_projects_q1/blob/main/hangman_game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

word_list = ["apple", "beautiful", "potato"]
lives = 6
chosen_word = random.choice(word_list)
display = ["_"] * len(chosen_word)

hangman_stages = [
    """
       ------
       |    |
       |    O
       |   /|\\
       |   / \\
       |
    """,
    """
       ------
       |    |
       |    O
       |   /|\\
       |   /
       |
    """,
    """
       ------
       |    |
       |    O
       |   /|\\
       |
       |
    """,
    """
       ------
       |    |
       |    O
       |   /|
       |
       |
    """,
    """
       ------
       |    |
       |    O
       |    |
       |
       |
    """,
    """
       ------
       |    |
       |    O
       |
       |
       |
    """,
    """
       ------
       |    |
       |
       |
       |
       |
    """
]

game_over = False

while not game_over:
    print(hangman_stages[lives])
    print(" ".join(display))

    guessed_letter = input("Guess a letter: ").lower()

    if guessed_letter in chosen_word:
        for position in range(len(chosen_word)):
            if chosen_word[position] == guessed_letter:
                display[position] = guessed_letter
    else:
        lives -= 1
        if lives == 0:
            game_over = True
            print(hangman_stages[lives])
            print("You lose! The word was:", chosen_word)
            break

    if "_" not in display:
        game_over = True
        print(" ".join(display))
        print("You win!")
# Out:
#        ------
#        |    |
#        |
#        |
#        |
#        |
#
# _ _ _ _ _ _
# Guess a letter: p
#
#        ------
#        |    |
#        |
#        |
#        |
#        |
#
# p _ _ _ _ _
# Guess a letter: l
#
#        ------
#        |    |
#        |    O
#        |
#        |
#        |
#
# p _ _ _ _ _
# Guess a letter: l
#
#        ------
#        |    |
#        |    O
#        |    |
#        |
#        |
#
# p _ _ _ _ _
# Guess a letter: f
#
#        ------
#        |    |
#        |    O
#        |   /|
#        |
#        |
#
# p _ _ _ _ _
# Guess a letter: e
#
#        ------
#        |    |
#        |    O
#        |   /|\
#        |
#        |
#
# p _ _ _ _ _
# Guess a letter: w
#
#        ------
#        |    |
#        |    O
#        |   /|\
#        |   /
#        |
#
# p _ _ _ _ _
# Guess a letter: f
#
#        ------
#        |    |
#        |    O
#        |   /|\
#        |   / \
#        |
#
# You lose! The word was: potato
